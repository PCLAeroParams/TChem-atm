# %%
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import numpy as np
import os
os.getcwd()
# Out:
# '/Users/odiazib/Documents/p-clap/TChem-atm/src/examples/runs/atmospheric_chemistry/CarbonBond05'

# %%
font = {'size'   : 13}
matplotlib.rc('font', **font)

# %%
data = np.genfromtxt("full_gas.dat", dtype=str)
Header = (data[0,:]).tolist()
solTchem = (data[1:,:]).astype(float)

# %%
x=solTchem[:,Header.index('t')]/3600

# %%
plt.figure(figsize=[6,4])
plt.plot(x,solTchem[:,Header.index('OH')],'m',label='OH')
plt.plot(x,solTchem[:,Header.index('O')],'r',label='O')
plt.plot(x,solTchem[:,Header.index('O3')],'k',label='$\mathrm{O_3}$')
# plt.plot(x,solTchem[:,Header.index('NO')])
plt.plot(x,solTchem[:,Header.index('NO2')],'g',label='$\mathrm{NO_2}$')
plt.xlim([0,25])
plt.ylim([0,2.e-6])
plt.ylabel('Concentration '+ r'[$\mathrm{\frac{mol}{m^{-3}}}$]',fontsize=16)
plt.xlabel('Time [h]',fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend()
plt.savefig('species_concentration.pdf',bbox_inches='tight')
